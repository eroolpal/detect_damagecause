# %% [markdown]
# <a href="https://colab.research.google.com/github/eroolpal/detect_damagecause/blob/master/Copy_of_firefloodearthfraudnew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *

# %%
folder = 'fire'
file = 'urls_fire.csv'

# %%
path = Path('data/damage')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-25fff3e0-cd60-43da-bd81-e61f0ece6bf7" name="files[]" multiple disabled />
#      <output id="result-25fff3e0-cd60-43da-bd81-e61f0ece6bf7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving firedamagedbuilding1.csv to firedamagedbuilding1.csv

# %%
# !mv firedamagedbuilding1.csv data/damage/urls_fire.csv

# %%
classes = ['fire','flood','earthquake', 'fraud']

# %%
download_images(path/file, dest, max_pics=300)

# %%
folder = 'flood'
file = 'urls_flood.csv'

# %%
path = Path('data/damage')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-34ebb4ba-6dda-41d0-986a-d526716b7154" name="files[]" multiple disabled />
#      <output id="result-34ebb4ba-6dda-41d0-986a-d526716b7154">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving flooddamagedbuilding1.csv to flooddamagedbuilding1.csv

# %%
# !mv flooddamagedbuilding1.csv data/damage/urls_flood.csv

# %%
classes = ['fire','flood','earthquake', 'fraud']

# %%
download_images(path/file, dest, max_pics=300)

# %%
folder = 'earthquake'
file = 'urls_earthquake.csv'

# %%
path = Path('data/damage')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b5549c09-61cc-4dbf-8fd7-7b53d3e6d29a" name="files[]" multiple disabled />
#      <output id="result-b5549c09-61cc-4dbf-8fd7-7b53d3e6d29a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving earthquakedamagedbuilding.csv to earthquakedamagedbuilding.csv

# %%
# !mv earthquakedamagedbuilding.csv data/damage/urls_earthquake.csv

# %%
classes = ['fire','flood','earthquake', 'fraud']

# %%
download_images(path/file, dest, max_pics=300)

# %%
folder = 'fraud'
file = 'urls_fraud.csv'

# %%
path = Path('data/damage')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-813e45a7-63c8-4c0a-9f33-86ed056bb705" name="files[]" multiple disabled />
#      <output id="result-813e45a7-63c8-4c0a-9f33-86ed056bb705">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving housegood.csv to housegood.csv

# %%
# !mv housegood.csv data/damage/urls_fraud.csv

# %%
classes = ['fire','flood','earthquake', 'fraud']

# %%
download_images(path/file, dest, max_pics=300)

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['earthquake', 'fire', 'flood', 'fraud']

# %%
data.show_batch(rows=4, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['earthquake', 'fire', 'flood', 'fraud'], 4, 904, 226)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
#defaults.device= torch.device('gpu')
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.935372</td>
#       <td>1.198055</td>
#       <td>0.362832</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.481965</td>
#       <td>0.866998</td>
#       <td>0.296460</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.216303</td>
#       <td>0.884655</td>
#       <td>0.269911</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.032355</td>
#       <td>0.876711</td>
#       <td>0.287611</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.737008</td>
#       <td>0.839628</td>
#       <td>0.278761</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.619396</td>
#       <td>0.786207</td>
#       <td>0.261062</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# Clean up the text

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %%
#ImageCleaner(ds, idxs, path, duplicates=True)

# %% [markdown]
# Putting your model in production

# %%
learn.export()

# %%
defaults.device = torch.device('cpu')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-844f3e53-fdcd-479f-b77a-f8db2602780e" name="files[]" multiple disabled />
#      <output id="result-844f3e53-fdcd-479f-b77a-f8db2602780e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving earthquake_house.jpg to earthquake_house.jpg

# %%
img = open_image('earthquake_house.jpg')
img
# Out:
# Image (3, 281, 500)

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category earthquake
