# %% [markdown]
# <a href="https://colab.research.google.com/github/eroolpal/detect_damagecause/blob/master/firefloodearthfraud1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *

# %%
folder = 'fire'
file = 'urls_fire.csv'

# %%
path = Path('data/damage')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ccb7c50c-e57a-4790-8f4a-c421bb89620d" name="files[]" multiple disabled />
#      <output id="result-ccb7c50c-e57a-4790-8f4a-c421bb89620d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving firedamaged.csv to firedamaged.csv

# %%
# !mv firedamaged.csv data/damage/urls_fire.csv

# %%
classes = ['fire','flood','earthquake', 'fraud']

# %%
download_images(path/file, dest, max_pics=300)

# %%
folder = 'flood'
file = 'urls_flood.csv'

# %%
path = Path('data/damage')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-17798175-2f2f-410f-bc7e-d7757d6e2bf4" name="files[]" multiple disabled />
#      <output id="result-17798175-2f2f-410f-bc7e-d7757d6e2bf4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving flooddamaged.csv to flooddamaged.csv

# %%
# !mv flooddamaged.csv data/damage/urls_flood.csv

# %%
classes = ['fire','flood','earthquake', 'fraud']

# %%
download_images(path/file, dest, max_pics=300)

# %%
folder = 'earthquake'
file = 'urls_earthquake.csv'

# %%
path = Path('data/damage')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bd1de8fe-4526-48fe-ac40-39b050a57ac0" name="files[]" multiple disabled />
#      <output id="result-bd1de8fe-4526-48fe-ac40-39b050a57ac0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving earthquakedamaged.csv to earthquakedamaged.csv

# %%
# !mv earthquakedamaged.csv data/damage/urls_earthquake.csv

# %%
classes = ['fire','flood','earthquake', 'fraud']

# %%
download_images(path/file, dest, max_pics=300)

# %%
folder = 'fraud'
file = 'urls_fraud.csv'

# %%
path = Path('data/damage')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-60726262-d432-49b9-bd80-1e130f35d79d" name="files[]" multiple disabled />
#      <output id="result-60726262-d432-49b9-bd80-1e130f35d79d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving housegood.csv to housegood.csv

# %%
# !mv housegood.csv data/damage/urls_fraud.csv

# %%
classes = ['fire','flood','earthquake', 'fraud']

# %%
download_images(path/file, dest, max_pics=300)

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['earthquake', 'fire', 'flood', 'fraud']

# %%
data.show_batch(rows=4, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['earthquake', 'fire', 'flood', 'fraud'], 4, 885, 221)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 159MB/s]

# %%
#defaults.device= torch.device('gpu')
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.792453</td>
#       <td>1.348178</td>
#       <td>0.411765</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.378959</td>
#       <td>1.056947</td>
#       <td>0.303167</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.124432</td>
#       <td>1.040214</td>
#       <td>0.285068</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.990303</td>
#       <td>1.019990</td>
#       <td>0.312217</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.222475</td>
#       <td>0.906092</td>
#       <td>0.253394</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.236220</td>
#       <td>0.884504</td>
#       <td>0.271493</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# Clean up the text

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %%
#ImageCleaner(ds, idxs, path, duplicates=True)

# %% [markdown]
# Putting your model in production

# %%
learn.export()

# %%
defaults.device = torch.device('cpu')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-844f3e53-fdcd-479f-b77a-f8db2602780e" name="files[]" multiple disabled />
#      <output id="result-844f3e53-fdcd-479f-b77a-f8db2602780e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving earthquake_house.jpg to earthquake_house.jpg

# %%
img = open_image('earthquake_house.jpg')
img
# Out:
# Image (3, 281, 500)

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category earthquake
